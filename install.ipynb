# %%
# %pip install -r requirements.txt
# Out:
# ...
#      ---------------------------------------- 0.0/86.0 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/86.0 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/86.0 kB ? eta -:--:--
#      ------------------ ------------------- 41.0/86.0 kB 245.8 kB/s eta 0:00:01
#      ------------------------------- ------ 71.7/86.0 kB 393.8 kB/s eta 0:00:01
#      -------------------------------------- 86.0/86.0 kB 404.9 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/232.6 kB ? eta -:--:--
#      ----------------------- -------------- 143.4/232.6 kB 2.9 MB/s eta 0:00:01
#      -------------------------------------- 232.6/232.6 kB 2.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/977.5 kB ? eta -:--:--
#      ---------------------- -------------- 583.7/977.5 kB 17.9 MB/s eta 0:00:01
# ...
